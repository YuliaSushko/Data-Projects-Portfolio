# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:3em;color:#0ab7fb">Capstone Project: Loan Default Prediction

# %% [markdown]
# #  Table of Contents
#
# 1. **[Executive Summary](#executive_summary)**
# 2. **[Problem and Solution Summary](#solution)**
# 3. **[Recommendations for Implementation](#implementation)**
# 4. **[Solution Code](#code)**

# %% [markdown]
# <a name="executive_summary"> </a>
# # 1. Executive Summary
# <table align="left">
#     <tr>
#         <td>    <div align="left", style="font-size:125%">
#                 <font color="#21618C">
#                     <b> What are the key takeaways? What are the key next steps?
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# In terms of this project **Decision Tree with Hyperparameter tuned** is proposed as the most efficient model for predicting default clients. This model is **able to catch up to 76% of potential defaulters and result in at least -3% of non performing assets’ share** for the Bank. It determines DEBTING missing data, DEBTINC, CLAGE, DELINQ and DEROG as key features able to predict whether a client is going to default or not,  yet its overall algorithm and process are highly interpretable.
#
# At the same time there are certain drawbacks  which are to be considered and challenged in the future. Thus, the model doesn’t handle biases perfectly, heavily prioritizing one feature only (DEBTINC missing values) with other features left with too low weights. Besides, in its effort to minimize the risky operations it tends to increase the number of falsely predicted defaulters. This causes the problem of an imbalanced portfolio and of how not to reject a good client when trying to minimize the risks.
#
# In order to handle these challenges it’s recommended to further optimize the model, deploy feature engineering to enhance its accuracy and robustness, explore other ML models (Random Forest, XGBoost, kNN, LDA, QDA, SVM, etc. ), revise the approach to collecting data (missing data in particular). It’s also recommended to take a step to educate the staff processing the model and be able to intervene more in some ambiguous cases and design loan values thresholding/tiers for different categories of customers.

# %% [markdown]
# <a name="solution"> </a>
# # 2. Problem and Solution Summary
# <table align="left">
#     <tr>
#         <td>    <div align="left", style="font-size:125%">
#                 <font color="#21618C">
#                     <b> What problem was being solved? What are the key points that describe the final proposed solution design? Why is this a 'valid' solution that is likely to solve the problem?
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Problem Summary
#
# Interests in the form of home loans are a very important source of retail bank profit. Default loans (bad loans, or NPA - non performing assets) make up 20% of all the loans approved and diminish profits drastically. That's why it is so crucial for the Bank to be explicitly prudent when approving loans. On the other hand, the approval process for the loans is multifaceted. Through this process, the Bank tries to check the creditworthiness of the applicant on the basis of a manual study of various aspects of the application. The entire process is not only effort-intensive but also prone to wrong judgment/approval owing to human error and biases.
#
# The key objective of this project is to **build an efficient and statistically sound classification model detecting clients who are more likely to default**. At the same time the model has to be simple, transparent and interpretable enough, that's why interpretability is going to play an important role when determining the best performing model. The Bank needs to know what features have the highest influence on defaults, why and how this should be treated.
#
# The models designed within the project provide overall understanding about the major factors alarming possible default, reveal some crucial 'blind zones' which should be taken care of and additional challenges which the Bank may face utilizing Machine Learning techniques.
#
# ## Solution Summary
#
# Different classification models and techniques were utilized in terms of the project. They include: Logistic Regression, Decision Trees, Random Forests and a few Boosting Models. Since default clients are the main risk for the Bank in order to maximize correct predictions (predicted default = actual default, true positive) and minimize wrong ones (predicted non-default = actual default, false negative) Recall was chosen as a key model evaluation criterion.
#
# The final proposed solution is **Decision Tree with Hyperparameter tuned**. The Decision Tree provides a clear and interpretable algorithm predicting whether a client is going to default or not. Among the key features able to recognize potential default loan in early stage of the loan approval are:
#
# * **DEBTINC missing data**: debt-to-income ratio missing data is the primary point detecting potential default;
# * **DEBTINC** value which has positive impact on default (higher ratios mean higher probability of default);
# * **DELINQ**: delinquent credit lines may signalize about possible default as well;
# * **CLAGE** which has negative impact on default: the higher it is (the older the oldest credit line is, in months) the lower chances for default are;
# * **DEROG** - positive influence on default.
#
# Decision Tree with Hyperparameter Tuned stands out from the rest because it:
# * performs best in predicting defaults (catches up to 76% of potential defaults);
# * gives the highest interpretability (easy to follow and explain) - Fig.3;
# * looks more reliable and accurate (train/test predictions are balanced, no overfitting)
#
# Among the weaknesses of the model:
# * doesn’t handle biases perfectly and heavily prioritizes one feature only (DEBTINC missing values) with other features given far lower weights, behaves narrow-seighting;
# * tends to increase the number of falsely predicted defaulters: trying to minimize the risks it might limit potential profit opportunities, rejecting good clients.

# %% [markdown]
# <a name="implementation"> </a>
# # 3. Recommendations for Implementation
# <table align="left">
#     <tr>
#         <td>    <div align="left", style="font-size:125%">
#                 <font color="#21618C">
#                     <b> What are some key recommendations to implement the solutions? What are the key actionables for stakeholders? What is the expected benefit and/or costs? What are the key risks and challenges? What further analysis needs to be done or what other associated problems need to be solved?
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# With the proposed model applied the Bank can catch up to 76% of potential defaulters resulting in (Fig. 4): lower share of default loans - both in volume and value. This means at least -3%  decrease in NPA (non performing assets).
# In other words, the model is going to increase default loans in quantity from 4 to 3 out of 20, in value - 82 to 85 out of 100 would be secure investments (safe credits).
#
# Still, taking into account the weaknesses of the model the following is recommended to the Bank:
# * be especially cautious to clients with high DEBTINC, DELINQ and DEROG along with low CLAGE, since these features predetermine defaulters a lot;
# * encourage efficient human intervention and more in-depth analysis when dealing with edgy clients who have a slight skew towards default - they may still be good clients (the staff has to be well educated about how the process works and the logic behind);
# * start designing conditional loan value thresholding/tiers model as another lever to keep the most proper balance between ‘good’ and ‘bad’ clients.
#
# Along with that the next steps are worth planning:
# *further optimization of the model: each p.p. added to Recall or Precision will result in better optimized client portfolio and profits gained;
# * feature engineering to enhance model’s accuracy and robustness;
# other models exploration, such as Random Forest, XGBoost, kNN, LDA, QDA, SVM, etc.
# * collecting data approaches revision, especially in terms of missing values: missing data significantly influences the model becoming its key predictor and bias-empowering factor at the same time.

# %% [markdown]
# ### Data description
#
#
# The Home Equity dataset (HMEQ) contains baseline and loan performance information for 5,960 recent home equity loans. The target (BAD) is a binary variable that indicates whether an applicant has ultimately defaulted or has been severely delinquent. This adverse outcome occurred in 1,189 cases (20 percent). 12 input variables were registered for each applicant.
#
#
# * **BAD:** 1 = Client defaulted on loan, 0 = loan repaid
#
# * **LOAN:** Amount of loan approved.
#
# * **MORTDUE:** Amount due on the existing mortgage.
#
# * **VALUE:** Current value of the property.
#
# * **REASON:** Reason for the loan request. (HomeImp = home improvement, DebtCon= debt consolidation which means taking out a new loan to pay off other liabilities and consumer debts)
#
# * **JOB:** The type of job that loan applicant has such as manager, self, etc.
#
# * **YOJ:** Years at present job.
#
# * **DEROG:** Number of major derogatory reports (which indicates a serious delinquency or late payments).
#
# * **DELINQ:** Number of delinquent credit lines (a line of credit becomes delinquent when a borrower does not make the minimum required payments 30 to 60 days past the day on which the payments were due).
#
# * **CLAGE:** Age of the oldest credit line in months.
#
# * **NINQ:** Number of recent credit inquiries.
#
# * **CLNO:** Number of existing credit lines.
#
# * **DEBTINC:** Debt-to-income ratio (all your monthly debt payments divided by your gross monthly income. This number is one way lenders measure your ability to manage the monthly payments to repay the money you plan to borrow.

# %% [markdown]
# <a name="code"> </a>
# # 4. Solution Code
# <table align="left">
#     <tr>
#         <td>    <div align="left", style="font-size:125%">
#                 <font color="#21618C">
#                            <b>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### **Import the necessary libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier

from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,precision_score,recall_score,f1_score, precision_recall_curve

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier

import scipy.stats as stats

from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Brief Summaries on EDA
#
# ### Data Description
#
# * The dataset analyzed consists of **5960 rows and 13 columns**.
# * The **majority of data is of numeric data type**.
# * There are a lot of **missing values in the datatset. 11 out of 13 variables** have missing values, **2500 out of 5960 observations** have at least one missing value. he % of missing value for different variables varies from 2% to 21%. Such huge ratios of missing values, both column- and row-wise, mean we need to handle those properly.
#
#
# ### Data Cleaning
#
# * Together with 'BAD' variable we've reassigned the data type for 'REASON' and 'JOB': this way we've made these variable comparatively easier to store.
# * We have handled the **missing values by imputing median for numerical variables and mode - for categorical**. Yet, we've implied binary flags indicators in order to track missing values and understand whether we deal with original data or imputed one.
# * Having observed a lot of **outliers for the majority of data subsets** we have also handled them with trimming - a separate dataset with outliers treated is supposed to be used for Logistic Regression Modeling since this model is especially sensitive to outliers. For the rest of the models we've used the datasets with outliers as they are the part of original data and real-life problem we cannot skip.
# * **The independent variables in this dataset have different scales** which may lead to significant biases and wrong conclusions. Not to misguide our Machine Learning models we've used Standard Scaler and implied Feature Scaling which transfered all the data in terms of comparable scales.
#
#
# ### Observations from Exploration Data Analysis
#
# * **The dataset is imbalanced: 80% of observations refer to paid loans ('BAD': 0) and approx. 20% - to default loans ('BAD': 1)**. When working with ML models we've stratified the training/testing dataset for some models with this taken into account. Yet, we have also treated this using class weights giving more priority towards the class of default loans since it is our main focus (that's what we need to predict).
# * We've found out that **average loan client** of the bank will have:
#
#        - approved LOAN of 18000 approx.
#        - MORTGAGE of around 74000
#        - total properties' VALUE of nearly 100000
#        - years (YOJ) at current company/position of around 9 years
#        - the oldest credit line (CLAGE) aged 180 months
#        - total number of credit lines (CLNO) of around 20
#        - 0 degoratory reports (DEROG) and deliquent credit lines (DELINQ), for over 70% of clients
#        - 1 recent credit inquiry
#        - and debt consolidation (DebtCon) as a reason for loan application - 65% of cases
#
# * Still, the **'average' non-default client is very different from 'average' non-default**, especially in terms of such features as: **DEBTINC, CLAGE, DEROG, CLNO, VALUE, MORTDUE**, etc. This has helped us to make some preliminary assumptions about what features could be of major importance for ML algorithms. For instance, **'BAD' clients (default) had higher DEBTINC (debt-to-income ratio) and lower CLAGE (age of the oldest credit line)** in comparison to non-defaulters. They also have **higher DELINQ and DEROG values** which looks reasonable and easy to understand.
# * Among the **JOBS with the worst pay-off statistics (higher ratio of default loans) there are: Sales, Self-employed and Manager**. The least default ratio can be observed for Office (13%) and Professional Executives (below 17%), so potentially clients with this kind of jobs are less likely to default. Still, the majority of bank clients refer to two jobs - Other (40%).

# %%
# Read the dataset
hm = pd.read_csv("hmeq.csv")

# %%
# Copy data to another variable to avoid any changes to original data
data = hm.copy()

# %%
# Display first five rows
data.head()
# Out:
#    BAD  LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0    1  1100  25860.0   39025.0  HomeImp   Other  10.5    0.0     0.0
# 1    1  1300  70053.0   68400.0  HomeImp   Other   7.0    0.0     2.0
# 2    1  1500  13500.0   16700.0  HomeImp   Other   4.0    0.0     0.0
# 3    1  1500      NaN       NaN      NaN     NaN   NaN    NaN     NaN
# 4    0  1700  97800.0  112000.0  HomeImp  Office   3.0    0.0     0.0
#
#         CLAGE  NINQ  CLNO  DEBTINC
# 0   94.366667   1.0   9.0      NaN
# 1  121.833333   0.0  14.0      NaN
# 2  149.466667   1.0  10.0      NaN
# 3         NaN   NaN   NaN      NaN
# 4   93.333333   0.0  14.0      NaN

# %%
# Display last 5 rows
data.tail()
# Out:
#       BAD   LOAN  MORTDUE    VALUE   REASON    JOB   YOJ  DEROG  DELINQ  \
# 5955    0  88900  57264.0  90185.0  DebtCon  Other  16.0    0.0     0.0
# 5956    0  89000  54576.0  92937.0  DebtCon  Other  16.0    0.0     0.0
# 5957    0  89200  54045.0  92924.0  DebtCon  Other  15.0    0.0     0.0
# 5958    0  89800  50370.0  91861.0  DebtCon  Other  14.0    0.0     0.0
# 5959    0  89900  48811.0  88934.0  DebtCon  Other  15.0    0.0     0.0
#
#            CLAGE  NINQ  CLNO    DEBTINC
# 5955  221.808718   0.0  16.0  36.112347
# 5956  208.692070   0.0  15.0  35.859971
# 5957  212.279697   0.0  15.0  35.556590
# 5958  213.892709   0.0  16.0  34.340882
# 5959  219.601002   0.0  16.0  34.571519

# %%
# Check the shape of the data
data.shape
# Out:
# (5960, 13)

# %%
# Check info of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5960 entries, 0 to 5959
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BAD      5960 non-null   int64
#  1   LOAN     5960 non-null   int64
#  2   MORTDUE  5442 non-null   float64
#  3   VALUE    5848 non-null   float64
#  4   REASON   5708 non-null   object
#  5   JOB      5681 non-null   object
#  6   YOJ      5445 non-null   float64
#  7   DEROG    5252 non-null   float64
#  8   DELINQ   5380 non-null   float64
#  9   CLAGE    5652 non-null   float64
#  10  NINQ     5450 non-null   float64
#  11  CLNO     5738 non-null   float64
#  12  DEBTINC  4693 non-null   float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 605.4+ KB

# %%
# Check if there is any duplicated data
data.duplicated().sum()
# Out:
# 0

# %%
# Analyze the missing values - both in absolute and ratio equivalent simultaneously, column-wise

# Function to calculate missing values by column
def missing_values_table(data): 
        mis_val = data.isnull().sum() # total number
        mis_val_perc = data.isnull().sum()*100/len(data) # percentage of missing values
        mis_val_table = pd.concat([mis_val, mis_val_perc], axis=1) # a table which is to combine both - numbers and %
        
        mis_val_table_upd_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Missing to Total'})
        
        # Sorting the values in descending order
        mis_val_table_upd_columns = mis_val_table_upd_columns[mis_val_table_upd_columns.iloc[:,1] != 0].sort_values(
        '% of Missing to Total', ascending = False).round(1)
        
        # Summarizing some basic table info
        print ("This dataset has " + str(data.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_upd_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_upd_columns

# %%
missing_values_table(data)
# Out:
# This dataset has 13 columns.
# There are 11 columns that have missing values.
#          Missing Values  % of Missing to Total
# DEBTINC            1267                   21.3
# DEROG               708                   11.9
# DELINQ              580                    9.7
# MORTDUE             518                    8.7
# YOJ                 515                    8.6
# NINQ                510                    8.6
# CLAGE               308                    5.2
# JOB                 279                    4.7
# REASON              252                    4.2
# CLNO                222                    3.7
# VALUE               112                    1.9

# %%
missing_values_table(data).to_csv('missing_values.csv', index = False)
# Out:
# This dataset has 13 columns.
# There are 11 columns that have missing values.

# %%
# Graphical representation of missing values due to heatmap
figure = plt.figure(figsize=(16, 10))
sns.heatmap(data.T.isnull())
# Out:
# <AxesSubplot:>

# %%
# Check how many rows (Clients, row-wise check) do have at least one missing value
data.isnull().any(axis=1).sum()
# Out:
# 2596

# %%
# Check what is the maximum nu. missing values row-wise (client-wise)
# data.isnull().sum(axis = 1).sort_values(ascending = False)

# %%
# data[data.isnull().sum(axis = 1) >= 10]

# %%
# Convert the object type columns to categories - this reduces the data space required to store the dataframe
cols = data.select_dtypes(['object']).columns.tolist()

# adding target variable to this list as this is a classification problem and the target variable is categorical
cols.append('BAD')

# %%
cols
# Out:
# ['REASON', 'JOB', 'BAD']

# %%
# Change the data type of object type column to category. hint use astype() function
for i in cols:
    data[i] = data[i].astype("category")

# %%
# Check the info again and the datatype of different variable
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5960 entries, 0 to 5959
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BAD      5960 non-null   category
#  1   LOAN     5960 non-null   int64
#  2   MORTDUE  5442 non-null   float64
#  3   VALUE    5848 non-null   float64
#  4   REASON   5708 non-null   category
#  5   JOB      5681 non-null   category
#  6   YOJ      5445 non-null   float64
#  7   DEROG    5252 non-null   float64
#  8   DELINQ   5380 non-null   float64
#  9   CLAGE    5652 non-null   float64
#  10  NINQ     5450 non-null   float64
#  11  CLNO     5738 non-null   float64
#  12  DEBTINC  4693 non-null   float64
# dtypes: category(3), float64(9), int64(1)
# memory usage: 483.7 KB

# %%
# Analyze the summary statistics for numerical variables
data.describe().T
# Out:
#           count           mean           std          min           25%  \
# LOAN     5960.0   18607.969799  11207.480417  1100.000000  11100.000000
# MORTDUE  5442.0   73760.817200  44457.609458  2063.000000  46276.000000
# VALUE    5848.0  101776.048741  57385.775334  8000.000000  66075.500000
# YOJ      5445.0       8.922268      7.573982     0.000000      3.000000
# DEROG    5252.0       0.254570      0.846047     0.000000      0.000000
# DELINQ   5380.0       0.449442      1.127266     0.000000      0.000000
# CLAGE    5652.0     179.766275     85.810092     0.000000    115.116702
# NINQ     5450.0       1.186055      1.728675     0.000000      0.000000
# CLNO     5738.0      21.296096     10.138933     0.000000     15.000000
# DEBTINC  4693.0      33.779915      8.601746     0.524499     29.140031
#
#                   50%            75%            max
# LOAN     16300.000000   23300.000000   89900.000000
# MORTDUE  65019.000000   91488.000000  399550.000000
# ...

# %%
# The mean of numerical variables grouped by 'BAD'
numerical_col = data.select_dtypes(include=np.number).columns.tolist()
data.groupby(['BAD'])[numerical_col].mean()
# Out:
#              LOAN       MORTDUE          VALUE       YOJ     DEROG    DELINQ  \
# BAD
# 0    19028.107315  74829.249055  102595.921018  9.154941  0.134217  0.245133
# 1    16922.119428  69460.452973   98172.846227  8.027802  0.707804  1.229185
#
#           CLAGE      NINQ       CLNO    DEBTINC
# BAD
# 0    187.002355  1.032749  21.317036  33.253129
# 1    150.190183  1.782765  21.211268  39.387645

# %%
data.groupby(['BAD'])['LOAN'].sum()
# Out:
# BAD
# 0    90783100
# 1    20120400
# Name: LOAN, dtype: int64

# %% [markdown]
# **Insights**
#
# If compared to non-defaulterd **default clients have higher average values** for such features as:
# - **DEBTINC** (39.4 vs. 33.2 for non-defaulters), NINQ (1.8 to 1.0),
# - **NINQ** (1.8 to 1.0),
# - **DELINQ** (1.2 to 0.2),
# - **DEROG** (0.7 to 0.1).
#
# This group of variables has relatively lower average values for defaulters vs. non-defaulters:
# - LOAN (non-defaulters are being approved higher amounts of loans on average, 19000 to 17000 on average),
# - MORTDUE (non-defaluters have higher MORTDUE values, 75000 to 69000 approx.),
# - VALUE and YOJ.
#
# The same is if we apply median instead of mean. Having taken outliers into account this might be imcomplete picture though, still it gives some background for some preliminary assumptions about what features and why could be more important than the others.

# %%
#data.groupby(['BAD'])[numerical_col].describe().T

# %%
# Check summary for categorical data - Hint: inside describe function you can use the argument include=['category']
data.describe(include = ["category"]).T
# Out:
#        count unique      top  freq
# BAD     5960      2        0  4771
# REASON  5708      2  DebtCon  3928
# JOB     5681      6    Other  2388

# %%
# Check the count of unique values in each categorical column 
cols_cat = data.select_dtypes(['category'])

for i in cols_cat.columns:
    print('Unique values in',i, 'are :')
    print(data[i].value_counts())
    print('*'*40)
# Out:
# Unique values in BAD are :
# 0    4771
# 1    1189
# Name: BAD, dtype: int64
# ****************************************
# Unique values in REASON are :
# DebtCon    3928
# HomeImp    1780
# Name: REASON, dtype: int64
# ****************************************
# Unique values in JOB are :
# Other      2388
# ProfExe    1276
# Office      948
# Mgr         767
# Self        193
# Sales       109
# Name: JOB, dtype: int64
# ****************************************

# %%
# Check the percentage of unique values in each categorical column 
cols_cat = data.select_dtypes(['category'])

for i in cols_cat.columns:
    print('Unique values in',i, 'are :')
    print(data[i].value_counts(normalize = True))
    print('*'*40)
# Out:
# Unique values in BAD are :
# 0    0.800503
# 1    0.199497
# Name: BAD, dtype: float64
# ****************************************
# Unique values in REASON are :
# DebtCon    0.688157
# HomeImp    0.311843
# Name: REASON, dtype: float64
# ****************************************
# Unique values in JOB are :
# Other      0.420349
# ProfExe    0.224608
# Office     0.166872
# Mgr        0.135011
# Self       0.033973
# Sales      0.019187
# Name: JOB, dtype: float64
# ****************************************

# %% [markdown]
# ## **Exploratory Data Analysis (EDA) and Visualization**

# %% [markdown]
# ### **1. Univariate Analysis - Numerical Data**

# %%
# While doing uni-variate analysis of numerical variables we want to study their central tendency and dispersion.
# Let us write a function that will help us create boxplot and histogram for any input numerical variable.
# This function takes the numerical column as the input and returns the boxplots and histograms for the variable.
# Let us see if this helps us write faster and cleaner code.
def histogram_boxplot(feature, figsize=(15,10), bins = None):
    """ Boxplot and histogram combined
    feature: 1-d feature array
    figsize: size of fig (default (9,8))
    bins: number of bins (default None / auto)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(nrows = 2, # Number of rows of the subplot grid= 2
                                           sharex = True, # x-axis will be shared among all subplots
                                           gridspec_kw = {"height_ratios": (.25, .75)}, 
                                           figsize = figsize 
                                           ) # creating the 2 subplots
    sns.boxplot(feature, ax=ax_box2, showmeans=True, color='violet') # boxplot will be created and a star will indicate the mean value of the column
    sns.distplot(feature, kde=F, ax=ax_hist2, bins=bins,palette="winter") if bins else sns.distplot(feature, kde=False, ax=ax_hist2) # For histogram
    ax_hist2.axvline(np.mean(feature), color='green', linestyle='--') # Add mean to the histogram
    ax_hist2.axvline(np.median(feature), color='black', linestyle='-') # Add median to the histogram

# %%
# Build the histogram boxplot for Loan
histogram_boxplot(data['LOAN'])

# %%
# Build the histogram boxplot for Mortdue
histogram_boxplot(data['MORTDUE'])

# %%
# Build the histogram boxplot for Value
histogram_boxplot(data['VALUE'])

# %%
# Build the histogram boxplot for YOJ
histogram_boxplot(data['YOJ'])

# %%
# Build the histogram boxplot for CLAGE
histogram_boxplot(data['CLAGE'])

# %%
# Build the histogram boxplot for CLNO
histogram_boxplot(data['CLNO'])

# %%
# Build the histogram boxplot for DEBTINC
histogram_boxplot(data['DEBTINC'])

# %% [markdown]
# ### **2. Univariate Analysis - Categorical Data**

# %%
# Function to create barplots that indicate percentage for each category.
def perc_on_bar(plot, feature):
    '''
    plot
    feature: categorical feature
    the function won't work if a column is passed in hue parameter
    '''

    total = len(feature) # length of the column
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # height of the plot
        ax.annotate(percentage, (x, y), size = 12) # annotate the percentage 
        
    plt.show() # show the plot

# %%
#Build barplot for DELINQ
plt.figure(figsize=(15,5))
ax = sns.countplot(data["DELINQ"],palette='winter')
perc_on_bar(ax,data["DELINQ"])

# %%
#Build barplot for DEROG
plt.figure(figsize=(15,5))
ax = sns.countplot(data["DEROG"],palette='winter')
perc_on_bar(ax,data["DEROG"])

# %%
#Build barplot for NINQ
plt.figure(figsize=(15,5))
ax = sns.countplot(data["NINQ"],palette='winter')
perc_on_bar(ax,data["NINQ"])

# %%
#Build barplot for BAD
plt.figure(figsize=(15,5))
ax = sns.countplot(data["BAD"],palette='winter')
perc_on_bar(ax,data["BAD"])

# %%
#Build barplot for REASON
plt.figure(figsize=(15,5))
ax = sns.countplot(data["REASON"],palette='winter')
perc_on_bar(ax,data["REASON"])

# %%
#Build barplot for JOB
plt.figure(figsize=(15,5))
ax = sns.countplot(data["JOB"],palette='winter')
perc_on_bar(ax,data["JOB"])

# %% [markdown]
# ### **3. Bivariate Analysis: Continuous and Categorical Variables**

# %%
#BAD vs. LOAN
sns.boxplot(data["BAD"],data['LOAN'],palette="PuBu")
# Out:
# <AxesSubplot:xlabel='BAD', ylabel='LOAN'>

# %% [markdown]
# **Insights**
#
# The average amount for loan is slightly higher for non-defaulters. The total range is pretty much the same for defaulters and non-defaulters, with huge number of outliers for both.

# %%
# BAD vs. MORTDUE
sns.boxplot(data["BAD"],data['MORTDUE'],palette="PuBu")
# Out:
# <AxesSubplot:xlabel='BAD', ylabel='MORTDUE'>

# %%
# BAD vs. VALUE
sns.boxplot(data["BAD"],data['VALUE'],palette="PuBu")
# Out:
# <AxesSubplot:xlabel='BAD', ylabel='VALUE'>

# %%
# BAD vs. YOJ
sns.boxplot(data["BAD"],data['YOJ'],palette="PuBu")
# Out:
# <AxesSubplot:xlabel='BAD', ylabel='YOJ'>

# %% [markdown]
# **Insights**
#
# On average, the clients who paid their loans have a bit longer job experience at the latest place/position which probably makes them more reliable in terms of their duties.

# %%
# BAD vs. CLAGE
sns.boxplot(data["BAD"],data["CLAGE"],palette="PuBu")
# Out:
# <AxesSubplot:xlabel='BAD', ylabel='CLAGE'>

# %% [markdown]
# **Insights**
#
# 'BAD' clients (defaulters) have lower range and average values for CLAGE. We can assume that the older the oldest credit line of the client is the better: this client is more likely to pay the debts.

# %%
# BAD vs. DEBTINC
sns.boxplot(data["BAD"],data['DEBTINC'],palette="PuBu")
# Out:
# <AxesSubplot:xlabel='BAD', ylabel='DEBTINC'>

# %% [markdown]
# **Insights**
#
# Default clients have much wider spread for DEBTINC along with higher values for this feature. This is reasonable and will probably play the major role for the future ML models.

# %%
# BAD vs. VALUE
sns.boxplot(data["BAD"],data['VALUE'],palette="PuBu")
# Out:
# <AxesSubplot:xlabel='BAD', ylabel='VALUE'>

# %%
# JOB vs. LOAN
sns.boxplot(data['JOB'], data['LOAN'], palette="PuBu")
# Out:
# <AxesSubplot:xlabel='JOB', ylabel='LOAN'>

# %%
# JOB vs. MORTDUE
sns.boxplot(data['JOB'], data['MORTDUE'], palette="PuBu")
# Out:
# <AxesSubplot:xlabel='JOB', ylabel='MORTDUE'>

# %%
# JOB vs. VALUE
sns.boxplot(data['JOB'], data['VALUE'], palette="PuBu")
# Out:
# <AxesSubplot:xlabel='JOB', ylabel='VALUE'>

# %%
# JOB vs. CLAGE
# sns.boxplot(data['JOB'], data['CLAGE'], palette="PuBu")

# %%
# JOB vs. YOJ
# sns.boxplot(data['JOB'], data['YOJ'], palette="PuBu")

# %%
# JOB vs. DEBTINC
sns.boxplot(data['JOB'], data['DEBTINC'], palette="PuBu")
# Out:
# <AxesSubplot:xlabel='JOB', ylabel='DEBTINC'>

# %% [markdown]
# ### **4. Bivariate Analysis: Two Continuous Variables**

# %%
sns.scatterplot(data["VALUE"],data['MORTDUE'],palette="PuBu")
# Out:
# <AxesSubplot:xlabel='VALUE', ylabel='MORTDUE'>

# %% [markdown]
# **Insights**
#
# As seen below on the heatmap there is a strong correlation between VALUE and MORTDUE. The higher the value of the properties is the higher the MORTDUE is. Basically, this means the properties are still due to pay.

# %%
# LOAN vs. MORTDUE
# sns.scatterplot(data["LOAN"],data['MORTDUE'],palette="PuBu")

# %%
# MORTDUE vs. DEBTINC
# sns.scatterplot(data["DEBTINC"],data['MORTDUE'],palette="PuBu")

# %%
# LOAN vs. VALUE
# sns.scatterplot(data["LOAN"],data['VALUE'],palette="PuBu")

# %%
# LOAN vs. DEBTINC
# sns.scatterplot(data["LOAN"],data['DEBTINC'],palette="PuBu")

# %%
# LOAN vs. CLAGE
# sns.scatterplot(data["LOAN"],data['CLAGE'],palette="PuBu")

# %%
# LOAN vs. CLNO
# sns.scatterplot(data["LOAN"],data['CLNO'],palette="PuBu")

# %%
# MORTDUE vs. CLNO
# sns.scatterplot(data["MORTDUE"],data['CLNO'],palette="PuBu")

# %%
# MORTDUE vs. CLAGE
# sns.scatterplot(data["MORTDUE"],data['CLAGE'],palette="PuBu")

# %%
# MORTDUE vs. DEBTINC
# sns.scatterplot(data["MORTDUE"],data['DEBTINC'],palette="PuBu")

# %%
# CLNO vs. CLAGE
# sns.scatterplot(data["CLNO"],data['CLAGE'],palette="PuBu")

# %% [markdown]
# ### **5. Bivariate Analysis:  BAD vs Categorical Variables**

# %%
# Function to plot stacked bar charts for categorical columns
def stacked_plot(x):
    sns.set(palette='nipy_spectral')
    tab1 = pd.crosstab(x,data['BAD'],margins=True)
    print(tab1)
    print('-'*120)
    tab = pd.crosstab(x,data['BAD'],normalize='index')
    tab.plot(kind='bar',stacked=True,figsize=(10,5))
    plt.legend(loc='lower left', frameon=False)
    plt.legend(loc="upper left", bbox_to_anchor=(1,1))
    plt.show()

# %% [markdown]
# #### Plot stacked bar plot for for BAD and REASON

# %%
# Plot stacked bar plot for BAD and REASON
stacked_plot(data['REASON'])
# Out:
# BAD         0     1   All
# REASON
# DebtCon  3183   745  3928
# HomeImp  1384   396  1780
# All      4567  1141  5708
# ------------------------------------------------------------------------------------------------------------------------

# %%
# Plot stacked bar plot for BAD and JOB
stacked_plot(data['JOB'])
# Out:
# BAD         0     1   All
# JOB
# Mgr       588   179   767
# Office    823   125   948
# Other    1834   554  2388
# ProfExe  1064   212  1276
# Sales      71    38   109
# Self      135    58   193
# All      4515  1166  5681
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Insights**
#
# The worst loan statistics belongs to Sales (up to 25% of defaulters) and Self-Employed (up to 20% default) followed by Managers and Others. Lower than 'average' (20%) statistics of default goes to Office and Professional Executives. It will be interesting to see if this will be defined as important feature when applying different classification models.

# %% [markdown]
# ### **6. Multivariate Analysis**

# %% [markdown]
# #### Analyze Correlation Heatmap for Numerical Variables

# %%
# Separate numerical variables
numerical_col = data.select_dtypes(include=np.number).columns.tolist()

# Build correlation matrix for numerical columns
corr = data[numerical_col].corr()

# Plot the heatmap
plt.figure(figsize=(16,12))
sns.heatmap(corr,cmap='coolwarm',vmax=1,vmin=-1,
        fmt=".2f",
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
# Build pairplot for the data with hue = 'BAD'
plt.figure(figsize=(14, 14))

sns.pairplot(data, diag_kind='kde', corner = True)

# %%
# Scatterplot for the data with hue = 'BAD'
# MORTDUE vs. VALUE
plt.figure(figsize = (8, 8))
sns.scatterplot(x = 'MORTDUE', y = 'VALUE', data = data, hue = 'BAD')
# Out:
# <AxesSubplot:xlabel='MORTDUE', ylabel='VALUE'>

# %% [markdown]
# ### Treating missing values

# %%
cleaned_data = data.copy()

# %%
# For each column we create a binary flag for the row, if there is missing value in the row then 1, else 0. 
def add_binary_flag(df,col):
    '''
    df: It is the dataframe
    col: it is column which has missing values
    It returns a dataframe which has binary flag for missing values in column col
    '''
    new_col = str(col)
    new_col += '_missing_values_flag'
    df[new_col] = df[col].isna()
    return df

# %%
# Add binary flags
# List of columns that have missing values in it
missing_col = [col for col in cleaned_data.columns if cleaned_data[col].isnull().any()]

for colmn in missing_col:
    add_binary_flag(cleaned_data,colmn)

# %%
#  Treat Missing values in numerical columns with median and mode in categorical variables
#  Select numeric columns.
num_data = cleaned_data.select_dtypes('number')

# Select string and object columns.
cat_data = cleaned_data.select_dtypes('category').columns.tolist() #df.select_dtypes('object')

# Fill numeric columns with median.
cleaned_data[num_data.columns] = num_data.fillna(cleaned_data.median())

# Fill object columns with model.
for column in cat_data:
    mode = cleaned_data[column].mode()[0]
    cleaned_data[column] = cleaned_data[column].fillna(mode)

# %%
# Check if all the missing values have been treated
# cleaned_data.isnull().sum()

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5960 entries, 0 to 5959
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BAD                          5960 non-null   category
#  1   LOAN                         5960 non-null   int64
#  2   MORTDUE                      5960 non-null   float64
#  3   VALUE                        5960 non-null   float64
#  4   REASON                       5960 non-null   category
#  5   JOB                          5960 non-null   category
#  6   YOJ                          5960 non-null   float64
#  7   DEROG                        5960 non-null   float64
#  8   DELINQ                       5960 non-null   float64
#  9   CLAGE                        5960 non-null   float64
#  10  NINQ                         5960 non-null   float64
#  11  CLNO                         5960 non-null   float64
# ...

# %% [markdown]
# ### Treating Outliers

# %% [markdown]
# Outliers have been treated below in order to imply this updated dataset towards Logistic Regression Model since this algorithm is highly sensitive to outliers. For the rest of the models the outliers remain where they are being an important part of original real-life data.

# %%
# Treat the outliers for Logistic Regression model
def treat_outliers(df,col):
    '''
    treats outliers in a varaible
    col: str, name of the numerical varaible
    df: data frame
    col: name of the column
    '''
    
    Q1 = df[col].quantile(q = 0.25)  # 25th quantile
    Q3 = df[col].quantile(q = 0.75)  # 75th quantile
    IQR = Q3 - Q1   # IQR Range
    Lower_Whisker = Q1 - 1.5*IQR  # define lower whisker
    Upper_Whisker = Q3 + 1.5*IQR  # define upper Whisker
    df[col] = np.clip(df[col], Lower_Whisker, Upper_Whisker) 
        # all the values smaller than Lower_Whisker will be assigned value of Lower_whisker 
        # and all the values above Upper_Whisker will be assigned value of upper_Whisker 
    return df

def treat_outliers_all(df, col_list):
    '''
    treat outlier in all numerical variables
    col_list: list of numerical variables
    df: data frame
    '''
    for c in col_list:
        df = treat_outliers(df,c)
        
    return df

# %%
data_outliers = cleaned_data.copy()

# Get the list of numerical columns, except for DEROQ and DELINQ
numerical = data_outliers[['LOAN','MORTDUE','VALUE','YOJ', 'CLAGE', 'NINQ', 'CLNO', 'DEBTINC']].columns.tolist() 

data_outliers_treated = treat_outliers_all(data_outliers, numerical)

# %%
data_outliers_treated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5960 entries, 0 to 5959
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BAD                          5960 non-null   category
#  1   LOAN                         5960 non-null   float64
#  2   MORTDUE                      5960 non-null   float64
#  3   VALUE                        5960 non-null   float64
#  4   REASON                       5960 non-null   category
#  5   JOB                          5960 non-null   category
#  6   YOJ                          5960 non-null   float64
#  7   DEROG                        5960 non-null   float64
#  8   DELINQ                       5960 non-null   float64
#  9   CLAGE                        5960 non-null   float64
#  10  NINQ                         5960 non-null   float64
#  11  CLNO                         5960 non-null   float64
# ...

# %%
data_outliers_treated. describe().T
# The output table below shows the outliers have been successfully trimmed
# Out:
#           count          mean           std         min           25%  \
# LOAN     5960.0  18051.895973   9252.565294  1100.00000  11100.000000
# MORTDUE  5960.0  70517.313540  34463.827465  2063.00000  48139.000000
# VALUE    5960.0  98212.467603  44321.429121  8000.00000  66489.500000
# YOJ      5960.0      8.645109      6.953265     0.00000      3.000000
# DEROG    5960.0      0.224329      0.798458     0.00000      0.000000
# DELINQ   5960.0      0.405705      1.079256     0.00000      0.000000
# CLAGE    5960.0    178.226606     77.995604     0.00000    117.371430
# NINQ     5960.0      1.085403      1.312898     0.00000      0.000000
# CLNO     5960.0     20.994379      9.245170     0.00000     15.000000
# DEBTINC  5960.0     33.999967      5.953646    19.98306     30.763159
#
#                   50%            75%            max
# LOAN     16300.000000   23300.000000   41600.000000
# MORTDUE  65019.000000   88200.250000  148292.125000
# ...

# %% [markdown]
# ## **Model Building - Approach**
# 1. Data preparation
# 2. Partition the data into train and test set
# 3. Fit on the train data
# 4. Tune the model and prune the tree, if required
# 5. Test the model on test set

# %% [markdown]
# ## **Model Evaluation Criterion**
#
# Because our objective is to diminish the bank's losses caused by defaulted loans we need to make the most exhastive prediction about the clients who are more likely to default.
#
# Maximizing **RECALL as an evaluation criterion** will help us to **minimize the value of False Negatives** (clients predicted as non-defaulters who actually default): it is False Negatives which are the most malicios and costly mistake for the bank since it means unpredicted/unbalanced financial losses to it.
#
# The focus should be on increasing the Recall (minimizing the False Negatives) or, in other words, identifying the True Positives (the clients predicted to default who actually default) very well, so that the company can recognize defaulters in advance and decide properly if that's the risk which should be accepted, or not, or how to deal with that properly based on domain.

# %%
# Create metric function 
def metrics_score(actual, predicted):
    print(classification_report(actual, predicted))
    cm = confusion_matrix(actual, predicted)
    plt.figure(figsize=(8,5))
    sns.heatmap(cm, annot=True,  fmt='.2f', xticklabels=['Not default', 'Default'], yticklabels=['Not default', 'Default'])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab7fb">Model 1. Logistic Regression

# %% [markdown]
# #### **Data Preparation for Logistic Regression Model**

# %%
# Use the dataset with outliers treated (data_outliers_treated)
# Drop the dependent variable from the dataframe and create the X(independent variable) matrix
X1 = data_outliers_treated.drop(columns = 'BAD')

# Create dummy variables for the categorical variables - Hint: use the get_dummies() function
X1 = pd.get_dummies(X1, drop_first = True)

# Create y(dependent variable)
Y1 = data_outliers_treated['BAD']

# %%
#X1.info()

# %% [markdown]
# ### **Scaling the data**
#
# **The independent variables in this dataset have different scales** which may lead to significant biases and wrong conclusions. Not to misguide our Machine Learning models we are going to use Standard Scaler and imply Feature Scaling which will transfer all the data towards comparable scales.

# %%
# Scale the data
sc = StandardScaler()

X1_scaled = sc.fit_transform(X1)

X1_scaled = pd.DataFrame(X1_scaled, columns = X1.columns)

# %%
# Split the data into training and test set
# Stratify the data: give more priority to dependent variable dataset

x1_train, x1_test, y1_train, y1_test = train_test_split(X1, Y1, test_size = 0.3, random_state = 1, stratify = Y1)

# %%
# Define the Logistic regression model
# Imply class weights to rebalance the dataset - more priority to BAD = 1 as our key prediction target
logreg = LogisticRegression(random_state = 1, class_weight = {0: 0.2, 1: 0.8})

# Fit the model on the training data 
model  = logreg.fit(x1_train,y1_train)

# %%
# Predict for train set
y1_pred_train1 = logreg.predict(x1_train)

# Check the performance on the train dataset
metrics_score(y1_train, y1_pred_train1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.62      0.73      3340
#            1       0.31      0.70      0.43       832
#
#     accuracy                           0.63      4172
#    macro avg       0.60      0.66      0.58      4172
# weighted avg       0.78      0.63      0.67      4172

# %%
# Predict for test set
y1_pred_test1 = logreg.predict(x1_test)

# Check the performance on the test dataset
metrics_score(y1_test, y1_pred_test1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.62      0.73      1431
#            1       0.31      0.70      0.43       357
#
#     accuracy                           0.63      1788
#    macro avg       0.60      0.66      0.58      1788
# weighted avg       0.78      0.63      0.67      1788

# %% [markdown]
# **Insigths and observations**
#
# The **recall** for the model is 70% for both training and testing datasets which is pretty low value with our goal (minimizing False Negatives) taken into account. Still, all the figures are just the same for training and testing datasets which might indicate poor performance of the model in general. Yet, all the other metrics are low showing the model is not accurate enough and not performing well: the mistake of determining clients as non-defaulters while in fact they default remains high.

# %% [markdown]
# #### Let's check the coefficients, and check which variables are important and how they affect the process of loan approval

# %%
# Printing the coefficients of logistic regression
cols = X1.columns

coef_logreg = logreg.coef_

pd.DataFrame(coef_logreg,columns = cols).T.sort_values(by = 0, ascending = False)
# Out:
#                                     0
# DELINQ                       0.072109
# DEBTINC                      0.062600
# DEBTINC_missing_values_flag  0.037835
# DEROG                        0.037800
# NINQ                         0.028137
# VALUE_missing_values_flag    0.006291
# REASON_HomeImp               0.003406
# JOB_Self                     0.001676
# CLAGE_missing_values_flag    0.001625
# MORTDUE_missing_values_flag  0.001095
# JOB_Sales                    0.001061
# CLNO_missing_values_flag     0.000591
# JOB_Other                    0.000200
# VALUE                        0.000001
# MORTDUE                     -0.000006
# LOAN                        -0.000019
# REASON_missing_values_flag  -0.000068
# JOB_ProfExe                 -0.001680
# NINQ_missing_values_flag    -0.002062
# JOB_missing_values_flag     -0.002274
# YOJ_missing_values_flag     -0.002737
# DELINQ_missing_values_flag  -0.003401
# JOB_Office                  -0.003407
# DEROG_missing_values_flag   -0.004105
# ...

# %%
odds = np.exp(logreg.coef_[0]) # Finding the odds

# Adding the odds to a DataFrame and sorting the values
pd.DataFrame(odds, x1_train.columns, columns = ['odds']).sort_values(by = 'odds', ascending = False)
# Out:
#                                  odds
# DELINQ                       1.074772
# DEBTINC                      1.064601
# DEBTINC_missing_values_flag  1.038560
# DEROG                        1.038523
# NINQ                         1.028536
# VALUE_missing_values_flag    1.006311
# REASON_HomeImp               1.003412
# JOB_Self                     1.001678
# CLAGE_missing_values_flag    1.001626
# MORTDUE_missing_values_flag  1.001096
# JOB_Sales                    1.001062
# CLNO_missing_values_flag     1.000591
# JOB_Other                    1.000200
# VALUE                        1.000001
# MORTDUE                      0.999994
# LOAN                         0.999981
# REASON_missing_values_flag   0.999932
# JOB_ProfExe                  0.998321
# NINQ_missing_values_flag     0.997940
# JOB_missing_values_flag      0.997728
# YOJ_missing_values_flag      0.997267
# DELINQ_missing_values_flag   0.996605
# JOB_Office                   0.996599
# DEROG_missing_values_flag    0.995903
# ...

# %% [markdown]
# **Insights and observations**
#
# The **features with the strongest positive impact on default** are:
# * DELINQ
# * DEBTINC
# * DEBTING missing value flag
# * DEROG
# * NINQ
#
# The **features with the strongest negative impact on default** are:
# * YOJ
# * CLNO
# * CLAGE
# * DEROG missing value flag
# * JOB Office
#
# Thus, higher values of DELINQ, DEBTINC, DEBTINC missing data mean higher probability for a client to default.
# While higher YOJ, CLNO and CLAGE mean higher probability for a client not to default. Which seems reasonable and explainable.
#
# We've also transfered the coefficients which are difficult to read to odds which haven't given drastic differentiation between default and non-default clients. For instance, the odds of clients with higher DELINQ defaulting are only 7% higher that the odds of a client with a zero o low DELINQ. For the rest of the features these differences are even lower.
#
# We can see the model doesn't make it possible to predict precisely on which clients are going to default and not.

# %% [markdown]
# ### **Think about it:**
# - The above Logistic regression model was build on the threshold of 0.5, can we use different threshold?
# - How to get an optimal threshold and which curve will help you achieve?
# - How does, accuracy, precision and recall change on the threshold?

# %% [markdown]
# We will built precision - recall curve in order to find the optimal threshold and rebuild our Logistic Regression Model.

# %%
# predict_proba gives the probability of each observation belonging to each class
y1_scores_logreg = logreg.predict_proba(x1_train) 

precisions_logreg, recalls_logreg, thresholds_logreg = precision_recall_curve(y1_train, y1_scores_logreg[:, 1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize = (10, 7))

plt.plot(thresholds_logreg, precisions_logreg[:-1], 'b--', label = 'precision')

plt.plot(thresholds_logreg, recalls_logreg[:-1], 'g--', label = 'recall')

plt.xlabel('Threshold')

plt.legend(loc = 'upper left')

plt.ylim([0, 1])

plt.show()

# %%
# Imply optimal threshold found out (0.65) to the model, using predict_proba function.
optimal_threshold1 = .65

y1_pred_train = logreg.predict_proba(x1_train)

metrics_score(y1_train, y1_pred_train[:, 1] > optimal_threshold1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87      3340
#            1       0.44      0.36      0.40       832
#
#     accuracy                           0.78      4172
#    macro avg       0.64      0.62      0.63      4172
# weighted avg       0.77      0.78      0.77      4172

# %%
optimal_threshold1 = .65

y1_pred_test = logreg.predict_proba(x1_test)

metrics_score(y1_test, y1_pred_test[:, 1] > optimal_threshold1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86      1431
#            1       0.43      0.36      0.39       357
#
#     accuracy                           0.78      1788
#    macro avg       0.64      0.62      0.63      1788
# weighted avg       0.76      0.78      0.77      1788

# %% [markdown]
# **Insights and observations**
#
# **Implying optimal threshold (.65) has helped us to increase precision (43% vs. 31%) but lead to significant drop in recall (36% vs. 70%)**. None of the models, neither with default threshold nor with the optimal level of it, didn't help us to improve Logistic Regression Model's performance and make it more applicable to our problem.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab7fb">Model 2. Decision Tree

# %% [markdown]
# ### Data Preparation for the tree based model

# %% [markdown]
# #### **Separating the target variable from other variables**

# %%
# Drop the dependent variable from the dataframe and create the X(independent variable) matrix
X = cleaned_data.drop(columns = 'BAD')

# Create dummy variables for the categorical variables - Hint: use the get_dummies() function
X = pd.get_dummies(X, drop_first = True)

# Create y(dependent variable)
Y = cleaned_data['BAD']

# %%
#X.info()

# %%
#X.describe().T

# %% [markdown]
# #### **Splitting the data into 70% train and 30% test set**

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 1, stratify = Y)

# %%
# Define Decision tree model with class weights class_weight={0: 0.2, 1: 0.8}
d_tree = DecisionTreeClassifier(class_weight = {0: 0.2, 1: 0.8}, random_state = 1, criterion = 'entropy')

# %%
# Fitting Decision tree model
d_tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={0: 0.2, 1: 0.8}, criterion='entropy',
#                        random_state=1)

# %%
# Checking performance on the training data
y_pred_train2 = d_tree.predict(x_train)

metrics_score(y_train, y_pred_train2)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3340
#            1       1.00      1.00      1.00       832
#
#     accuracy                           1.00      4172
#    macro avg       1.00      1.00      1.00      4172
# weighted avg       1.00      1.00      1.00      4172

# %% [markdown]
# The model is overfitting for training data.

# %%
# Checking performance on the testing data
y_pred_test2 = d_tree.predict(x_test)

metrics_score(y_test, y_pred_test2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1431
#            1       0.73      0.66      0.70       357
#
#     accuracy                           0.88      1788
#    macro avg       0.82      0.80      0.81      1788
# weighted avg       0.88      0.88      0.88      1788

# %%
# Plot the feature importance

importances = d_tree.feature_importances_

columns = X.columns

importance_d_tree = pd.DataFrame(importances, index = columns, columns = ['Importance']).sort_values(by = 'Importance', ascending = False)

plt.figure(figsize = (13, 13))

sns.barplot(importance_d_tree.Importance,importance_d_tree.index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab7fb">Model 3. Decision Tree with Hyperparameter Tuned

# %% [markdown]
# ### **Decision Tree - Hyperparameter Tuning**
#
# * Hyperparameter tuning is tricky in the sense that **there is no direct way to calculate how a change in the hyperparameter value will reduce the loss of your model**, so we usually resort to experimentation. We'll use Grid search to perform hyperparameter tuning.
# * **Grid search is a tuning technique that attempts to compute the optimum values of hyperparameters.**
# * **It is an exhaustive search** that is performed on the specific parameter values of a model.
# * The parameters of the estimator/model used to apply these methods are **optimized by cross-validated grid-search** over a parameter grid.
#
# **Criterion {“gini”, “entropy”}**
#
# The function to measure the quality of a split. Supported criteria are “gini” for the Gini impurity and “entropy” for the information gain.
#
# **max_depth**
#
# The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
#
# **min_samples_leaf**
#
# The minimum number of samples is required to be at a leaf node. A split point at any depth will only be considered if it leaves at least min_samples_leaf training samples in each of the left and right branches. This may have the effect of smoothing the model, especially in regression.
#
# You can learn about more Hyperpapameters on this link and try to tune them.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %% [markdown]
# #### Using GridSearchCV for Hyperparameter tuning on the model

# %%
# Choose the type of classifier, add basic settings - including class_weight
d_tree_tuned = DecisionTreeClassifier(random_state = 1, class_weight = {0: 0.2, 1: 0.8})

# Grid of parameters to choose from (got it through million of manual re-settings)
parameters = {
              'max_depth': np.arange(2, 7), 
              'criterion': ['gini', 'entropy'],
              'min_samples_leaf': np.arange(1,15,5),
              'max_features': ['auto', 'sqrt', None]
              }

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(recall_score, pos_label = 1)

# Run the grid search
grid_obj = GridSearchCV(d_tree_tuned, parameters, scoring = scorer, cv = 15)

# Fit the GridSearch on train dataset
grid_obj = grid_obj.fit(x_train, y_train)

# Set the clf to the best combination of parameters
d_tree_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
d_tree_tuned.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={0: 0.2, 1: 0.8}, max_depth=6,
#                        min_samples_leaf=11, random_state=1)

# %%
# Check performance on the training data based on the tuned model
y_pred_train3 = d_tree_tuned.predict(x_train)

metrics_score(y_train, y_pred_train3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92      3340
#            1       0.65      0.81      0.72       832
#
#     accuracy                           0.88      4172
#    macro avg       0.80      0.85      0.82      4172
# weighted avg       0.89      0.88      0.88      4172

# %%
# Checking performance on the training data based on the tuned model
y_pred_test3 = d_tree_tuned.predict(x_test)

metrics_score(y_test, y_pred_test3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      1431
#            1       0.64      0.76      0.69       357
#
#     accuracy                           0.87      1788
#    macro avg       0.79      0.82      0.80      1788
# weighted avg       0.88      0.87      0.87      1788

# %%
# predict_proba gives the probability of each observation belonging to each class
y_scores_d_tree_tuned = d_tree_tuned.predict_proba(x_train) 

precisions_d_tree_tuned, recalls_d_tree_tuned, thresholds_d_tree_tuned = precision_recall_curve(y_train, y_scores_d_tree_tuned[:, 1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize = (10, 7))

plt.plot(thresholds_d_tree_tuned, precisions_d_tree_tuned[:-1], 'b--', label = 'precision')

plt.plot(thresholds_d_tree_tuned, recalls_d_tree_tuned[:-1], 'g--', label = 'recall')

plt.xlabel('Threshold')

plt.legend(loc = 'upper left')

plt.ylim([0, 1])

plt.show()

# %% [markdown]
# **Insights and observations**
#
# With hyperparameter tuned we've been able to improve the recall to 76% vs. 66%. Simultaneously, with this gain in recall we've drastically lost in precision (64% vs. 73%). This means we've improved our prediction over False Negative clients (predicted non-defaulters who actually default) but failed to improve False Positives (predicted defaulters who do not default).
#
# **Precision** = (True Positive) / (True Positive + *False Positive*)
#
# **Recall** = (True Positive) / (True Positive + *False Negative*)
#
# This means **the model tends to overpredict defaulters tagging as defaulters those clients who are not necessarily default**. That, respectively, leads to less quantity of loans approved, less financial operations, less balanced portfolio and lower incomes as result. Thus, trying to solve one problem we might cause another one. This needs to be researched deeper in order to find out if there are any other trade-off options to find the optimal combination of Precision and Recall (threshold).

# %% [markdown]
# #### Plotting the Decision Tree

# %%
# Plot the decision tree and analyze it to build the decision rule
features = list(X.columns)
plt.figure(figsize = (20, 20))
tree.plot_tree(d_tree_tuned, feature_names = features, max_depth = 3, filled = True, fontsize = 9, node_ids = True, class_names = True)
plt.show()

# %% [markdown]
# **Insights and observations**
#
# The first separation takes place at root node which is **DEBTINC missing values**: if a client's data doesn't consist this ratio this increases the chances for a client to default, on the opposite this data available (not missing) makes a client less likele to default. Thus, we understand that there should be no gaps in client's personal file. And the problem of missing data is crucial to solve.
#
# Proceeding furhter we can see that clients with **DEBTINC below 43.7** are less likely to default, especially if they have zero or close to zero **DELINQ** filed.
#
# At the same time clients with higher DEBTING still can be good clients (able to pay) if their **CLAGE** is above 274. On the opposite, the clients with lower CLAGE are more likely to default.
#
# Thus, we can see that the most important features for the model are (see the graph below):
#
# * **DEBTINC missing values** (client with DEBTING missing data are more likely to result in default) - this factor is of top priority;
# * **DEBTINC** - positive impact on default: the higher it is the higher the probability of default is;
# * **DELINQ**: delinquent credit lines may signalize about possible default as well;
# * **CLAGE** - negative impact on default: the higher it is (the older the oldest credit line is, in months) the lower chances for default;
# * **DEROG** - positive influence on default (the same as with delinquent credit lines).
#
# Though the model doesn't perform perfect in terms of basic scores (we're going to work with some other models in order to reach better results) its **key strength is its interpretability and explainability: it's not a black box model, looks pretty transparent, easy to follow and explain**.

# %% [markdown]
# #### Features importances check up

# %%
# Plot the feature importance

importances = d_tree_tuned.feature_importances_

columns = X.columns

importance_d_tree_tuned = pd.DataFrame(importances, index = columns, columns = ['Importance']).sort_values(by = 'Importance', ascending = False)

plt.figure(figsize = (13, 13))

sns.barplot(importance_d_tree_tuned.Importance,importance_d_tree_tuned.index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %%
# Importance of features in the tree building

print (pd.DataFrame(d_tree_tuned.feature_importances_, columns = ["Importance"], index = x_train.columns).sort_values(by = 'Importance', ascending = False))
# Out:
#                              Importance
# DEBTINC_missing_values_flag    0.603084
# DEBTINC                        0.159253
# DELINQ                         0.084741
# CLAGE                          0.055585
# DEROG                          0.025165
# MORTDUE                        0.017625
# VALUE_missing_values_flag      0.017197
# YOJ                            0.016240
# VALUE                          0.008393
# CLNO                           0.005817
# REASON_missing_values_flag     0.003050
# LOAN                           0.002148
# JOB_Office                     0.001098
# JOB_ProfExe                    0.000603
# JOB_Sales                      0.000000
# CLNO_missing_values_flag       0.000000
# JOB_Other                      0.000000
# REASON_HomeImp                 0.000000
# JOB_missing_values_flag        0.000000
# NINQ_missing_values_flag       0.000000
# CLAGE_missing_values_flag      0.000000
# DELINQ_missing_values_flag     0.000000
# ...

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab7fb">Model 4. Random Forest Classifier

# %% [markdown]
# ### **Building a Random Forest Classifier**
#
# **Random Forest is a bagging algorithm where the base models are Decision Trees.** Samples are taken from the training data and on each sample a decision tree makes a prediction.
#
# **The results from all the decision trees are combined together and the final prediction is made using voting or averaging.**

# %%
# Define Random forest CLassifier
rf = RandomForestClassifier(random_state = 1, criterion = 'entropy', class_weight = {0:0.8, 1:0.2})
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(class_weight={0: 0.8, 1: 0.2}, criterion='entropy',
#                        random_state=1)

# %%
# Check performance on the training data
y_pred_train4 = rf.predict(x_train)
metrics_score(y_train, y_pred_train4)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3340
#            1       1.00      1.00      1.00       832
#
#     accuracy                           1.00      4172
#    macro avg       1.00      1.00      1.00      4172
# weighted avg       1.00      1.00      1.00      4172

# %%
# Checking performance on the test data
y_pred_test4 = rf.predict(x_test)
metrics_score(y_test, y_pred_test4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      1431
#            1       0.84      0.68      0.75       357
#
#     accuracy                           0.91      1788
#    macro avg       0.88      0.82      0.85      1788
# weighted avg       0.91      0.91      0.91      1788

# %% [markdown]
# As with Decision Tree the Random Forest Model is overfitting for the training data. And still, doesn't perform well enough on testing data.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab7fb">Model 5. Random Forest Classifier Tuned

# %% [markdown]
# ### **Tuning the Random Forest**

# %% [markdown]
# * Hyperparameter tuning is tricky in the sense that **there is no direct way to calculate how a change in the hyperparameter value will reduce the loss of your model**, so we usually resort to experimentation. We'll use Grid search to perform hyperparameter tuning.
# * **Grid search is a tuning technique that attempts to compute the optimum values of hyperparameters.**
# * **It is an exhaustive search** that is performed on the specific parameter values of a model.
# * The parameters of the estimator/model used to apply these methods are **optimized by cross-validated grid-search** over a parameter grid.
#
#
# **n_estimators**: The number of trees in the forest.
#
# **min_samples_split**: The minimum number of samples required to split an internal node:
#
# **min_samples_leaf**: The minimum number of samples required to be at a leaf node.
#
# **max_features{“auto”, “sqrt”, “log2”, 'None'}**: The number of features to consider when looking for the best split.
#
# - If “auto”, then max_features=sqrt(n_features).
#
# - If “sqrt”, then max_features=sqrt(n_features) (same as “auto”).
#
# - If “log2”, then max_features=log2(n_features).
#
# - If None, then max_features=n_features.
#
# You can learn more about Random Forest Hyperparameters from the link given below and try to tune them
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %% [markdown]
# #### **Warning:** This may take a long time depending on the parameters you tune.

# %%
# Choose the type of classifier. 
rf_tuned = RandomForestClassifier(random_state = 1)

# Grid of parameters to choose from
parameters = {
    "n_estimators": np.arange(10,110,10),
    "criterion": ['gini', 'entropy'],
    "min_samples_split": np.arange(2,20,5),
    "class_weight": ["balanced",{0: 0.2, 1: 0.8}],
    "min_samples_leaf": np.arange(1,15,5)
   }
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(recall_score, pos_label = 1)

# Run the grid search
grid_obj = GridSearchCV(rf_tuned, parameters, scoring = scorer, cv = 5)

#fit the GridSearch on train dataset
grid_obj = grid_obj.fit(x_train, y_train)

# Set the clf to the best combination of parameters
rf_tuned_base = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
rf_tuned.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Check performance on the training data
y_pred_train5 = rf_tuned.predict(x_train)

metrics_score(y_train, y_pred_train5)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3340
#            1       1.00      1.00      1.00       832
#
#     accuracy                           1.00      4172
#    macro avg       1.00      1.00      1.00      4172
# weighted avg       1.00      1.00      1.00      4172

# %%
# Check performace on test dataset
y_pred_test5 = rf_tuned.predict(x_test)

metrics_score(y_test, y_pred_test5)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      1431
#            1       0.84      0.68      0.75       357
#
#     accuracy                           0.91      1788
#    macro avg       0.88      0.82      0.85      1788
# weighted avg       0.91      0.91      0.91      1788

# %% [markdown]
# #### Plot the Feature importance of the tuned Random Forest

# %%
# Plot the feature importance

importances = rf_tuned.feature_importances_

columns = X.columns

importance_rf_tuned = pd.DataFrame(importances, index = columns, columns = ['Importance']).sort_values(by = 'Importance', ascending = False)

plt.figure(figsize = (13, 13))

sns.barplot(importance_rf_tuned.Importance,importance_rf_tuned.index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# **Insights**
# The performance of Random Forest Classifier with CVGridSearch tuned didn't show substantial improvement vs. Random Forest. Still, further hyperparameter tuning might help. The other good thing about Random Forest Tuned is the features the importance of which seems to be more balanced which decreases bias and makes the model more robust.

# %% [markdown]
# **Let's try to build other Machine Learning classification models: XGBoost, Adaboost, Gradient Boost**

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab7fb">Models 6 - 8. AdaBoost, Gradient Boost Classifier, XGBoost

# %%
# Installing the xgboost library using the 'pip' command.
# !pip install xgboost
# Out:
# ...
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sushk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sushk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sushk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sushk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sushk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\sushk\anaconda3\lib\site-packages)
# ...

# %%
# Importing the AdaBoostClassifier and GradientBoostingClassifier [Boosting]
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier

# Importing the XGBClassifier from the xgboost library
from xgboost import XGBClassifier

# %%
# Adaboost Classifier
adaboost = AdaBoostClassifier(random_state = 1)

# Fitting the model
adaboost.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(random_state=1)

# %%
# Checking performance on the training data
y_pred_train6 = adaboost.predict(x_train)

metrics_score(y_train, y_pred_train6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      3340
#            1       0.84      0.69      0.76       832
#
#     accuracy                           0.91      4172
#    macro avg       0.88      0.83      0.85      4172
# weighted avg       0.91      0.91      0.91      4172

# %%
# Checking performance on the testing data
y_pred_test6 = adaboost.predict(x_test)

metrics_score(y_test, y_pred_test6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      1431
#            1       0.84      0.59      0.70       357
#
#     accuracy                           0.90      1788
#    macro avg       0.87      0.78      0.82      1788
# weighted avg       0.89      0.90      0.89      1788

# %%
# Gradient Boost Classifier
gbc = GradientBoostingClassifier(random_state = 1)

# Fitting the model
gbc.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=1)

# %%
# Checking performance on the training data
y_pred_train7 = gbc.predict(x_train)

metrics_score(y_train, y_pred_train7)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      3340
#            1       0.89      0.74      0.81       832
#
#     accuracy                           0.93      4172
#    macro avg       0.91      0.86      0.88      4172
# weighted avg       0.93      0.93      0.93      4172

# %%
# Checking performance on the testing data
y_pred_test7 = gbc.predict(x_test)

metrics_score(y_test, y_pred_test7)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      1431
#            1       0.85      0.62      0.72       357
#
#     accuracy                           0.90      1788
#    macro avg       0.88      0.80      0.83      1788
# weighted avg       0.90      0.90      0.90      1788

# %%
# XGBoost Classifier
xgb = XGBClassifier(random_state = 1, eval_metric = 'logloss')

# Fitting the model
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=1, ...)

# %%
# Checking performance on the training data
y_pred_train8 = xgb.predict(x_train)

metrics_score(y_train, y_pred_train8)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3340
#            1       1.00      1.00      1.00       832
#
#     accuracy                           1.00      4172
#    macro avg       1.00      1.00      1.00      4172
# weighted avg       1.00      1.00      1.00      4172

# %%
# Checking performance on the testing data
y_pred_test8 = xgb.predict(x_test)

metrics_score(y_test, y_pred_test8)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      1431
#            1       0.89      0.72      0.80       357
#
#     accuracy                           0.93      1788
#    macro avg       0.91      0.85      0.88      1788
# weighted avg       0.92      0.93      0.92      1788

# %%
# Plot the feature importance

importances = xgb.feature_importances_

columns = X.columns

importance_xgb = pd.DataFrame(importances, index = columns, columns = ['Importance']).sort_values(by = 'Importance', ascending = False)

plt.figure(figsize = (13, 13))

sns.barplot(importance_xgb.Importance,importance_xgb.index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# ### **Comparing Model Performances**

# %%
def get_recall_score(model,flag=True,x_train=x_train,x_test=x_test):
    '''
    model : classifier to predict values of X

    '''
    a = [] # defining an empty list to store train and test results
    pred_train = model.predict(x_train)
    pred_test = model.predict(x_test)
    train_recall = metrics.recall_score(y_train,pred_train)
    test_recall = metrics.recall_score(y_test, pred_test)
    a.append(train_recall) # adding train recall to list 
    a.append(test_recall) # adding test recall to list
    
    # If the flag is set to True then only the following print statements will be dispayed. The default value is set to True.
    if flag == True: 
        print("Recall on training set : ",metrics.recall_score(y_train,pred_train))
        print("Recall on test set : ",metrics.recall_score(y_test,pred_test))
    
    return a # returning the list with train and test scores

# %%
##  Function to calculate precision score
def get_precision_score(model,flag=True,x_train=x_train,x_test=x_test):
    '''
    model : classifier to predict values of X

    '''
    b = []  # defining an empty list to store train and test results
    pred_train = model.predict(x_train)
    pred_test = model.predict(x_test)
    train_precision = metrics.precision_score(y_train,pred_train)
    test_precision = metrics.precision_score(y_test,pred_test)
    b.append(train_precision) # adding train precision to list
    b.append(test_precision) # adding test precision to list
    
    # If the flag is set to True then only the following print statements will be dispayed. The default value is set to True.
    if flag == True: 
        print("Precision on training set : ",metrics.precision_score(y_train, pred_train))
        print("Precision on test set : ",metrics.precision_score(y_test, pred_test))

    return b # returning the list with train and test scores

# %%
##  Function to calculate accuracy score
def get_accuracy_score(model,flag=True,x_train=x_train,x_test=x_test):
    '''
    model : classifier to predict values of X

    '''
    c = [] # defining an empty list to store train and test results
    train_acc = model.score(x_train,y_train)
    test_acc = model.score(x_test,y_test)
    c.append(train_acc) # adding train accuracy to list
    c.append(test_acc) # adding test accuracy to list
    
    # If the flag is set to True then only the following print statements will be dispayed. The default value is set to True.
    if flag == True:
        print("Accuracy on training set : ",model.score(x_train,y_train))
        print("Accuracy on test set : ",model.score(x_test,y_test))
    
    return c # returning the list with train and test scores

# %%
# Make the list of all the model names 

models = [d_tree, d_tree_tuned, rf, rf_tuned, adaboost, gbc, xgb]

# defining empty lists to add train and test results
acc_train = []
acc_test = []
recall_train = []
recall_test = []
precision_train = []
precision_test = []

# looping through all the models to get the accuracy,recall and precision scores
for model in models:
     # accuracy score
    j = get_accuracy_score(model,False)
    acc_train.append(j[0])
    acc_test.append(j[1])

    # recall score
    k = get_recall_score(model,False)
    recall_train.append(k[0])
    recall_test.append(k[1])

    # precision score
    l = get_precision_score(model,False)
    precision_train.append(l[0])
    precision_test.append(l[1])

# %%
# Mention the Model names in the list. for example 'Model': ['Decision Tree', 'Tuned Decision Tree'..... write the names of all the models built]

comparison_frame = pd.DataFrame({'Model':['Decision Tree', 'Decision Tree Tuned', 'Random Forest', 'Random Forest Tuned',
                                         'Adaboost', 'Gradient Boost', 'XGBoost'], 
                                          'Train_Accuracy': acc_train,
                                          'Test_Accuracy': acc_test,
                                          'Train_Recall': recall_train,
                                          'Test_Recall': recall_test,
                                          'Train_Precision': precision_train,
                                          'Test_Precision': precision_test}) 
comparison_frame
# Out:
#                  Model  Train_Accuracy  Test_Accuracy  Train_Recall  \
# 0        Decision Tree        1.000000       0.884228      1.000000
# 1  Decision Tree Tuned        0.875599       0.865772      0.814904
# 2        Random Forest        1.000000       0.910515      1.000000
# 3  Random Forest Tuned        1.000000       0.909955      1.000000
# 4             Adaboost        0.913231       0.896532      0.694712
# 5       Gradient Boost        0.929291       0.902125      0.737981
# 6              XGBoost        0.999281       0.926174      0.996394
#
#    Test_Recall  Train_Precision  Test_Precision
# 0     0.663866         1.000000        0.731481
# 1     0.756303         0.650048        0.638298
# 2     0.680672         1.000000        0.840830
# 3     0.677871         1.000000        0.840278
# 4     0.591036         0.842566        0.844000
# 5     0.619048         0.888567        0.850000
# 6     0.722689         1.000000        0.886598
